# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('Salary_dataset1.csv', index_col=0)

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
#show all columns
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
#data types of the columns
df.dtypes
# Out:
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
#checking any missing or null values
df.isnull().values.sum()
# Out:
# 0

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
plt.scatter(df['YearsExperience'],df['Salary'])
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
X=df.iloc[:,0:1]
Y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import  LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
LinearRegression()
# Out:
# LinearRegression()

# %%
X_test
# Out:
#     YearsExperience
# 1               1.4
# 0               1.2
# 14              4.6
# 9               3.8
# 21              7.2
# 19              6.1

# %%
Y_test
# Out:
# 1     46206.0
# 0     39344.0
# 14    61112.0
# 9     57190.0
# 21    98274.0
# 19    93941.0
# Name: Salary, dtype: float64

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([36834.63210301])

# %%
plt.scatter(df['YearsExperience'],df['Salary'])
plt.plot(X_train,lr.predict(X_train),color='yellow')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
m= lr.coef_

# %%
b = lr.intercept_

# %%
# y=mx+b
m * 1.4 + b
# Out:
# array([36834.63210301])

# %%
#checking the predictions
m * 4 + b
# Out:
# array([61715.55800514])

# %%
 # for 8 years of experience salary= 101303 so the predicted salary is close to it
m * 8 + b
# Out:
# array([99993.90554687])
